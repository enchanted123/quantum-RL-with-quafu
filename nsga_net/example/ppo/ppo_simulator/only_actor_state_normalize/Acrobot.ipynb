# %%
import tensorflow as tf

using_gpu_index = 0 # 使用的 GPU 号码
gpu_list = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_virtual_device_configuration(
        gpu_list[using_gpu_index],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024 * 4)]
    )

# %%
import cirq
import models.quantum_genotypes as genotypes

from models.quantum_models import generate_model_policy
from functools import reduce
env_name = "Acrobot-v1"

genotype = genotypes.ORI_TYPE_AB

n_qubits = 6 # Dimension of the state vectors in CartPole
# n_layers = 5 # Number of layers in the PQC
n_actions = 3 # Number of actions in CartPole

qubits = cirq.GridQubit.rect(1, n_qubits)
observables = [cirq.Z(qubits[0]), cirq.Z(qubits[1]), cirq.Z(qubits[2]), cirq.Z(qubits[3]), cirq.Z(qubits[4]), cirq.Z(qubits[5])] # Z_0*Z_1*Z_2*Z_3


# generate_model_policy(qubits, genotype, n_actions, beta, observables, env):
model = generate_model_policy(qubits, genotype, n_actions, 1., observables, env_name, using_H=True)
# Out:
# Acrobot-v1

# %%
from models.value_net import ValueNet

# %%
from IPython.core.display import HTML
from models.quantum_models import generate_circuit

circuit, params, inputs = generate_circuit(qubits, genotype, using_H=True)
display(HTML(f"<pre>{circuit}</pre>"))
# Out:
# <pre>(0, 0): ───H───Rx(theta0)────Ry(theta1)────Rz(theta2)────@───────────────────Rx(x2_0)───Rx(theta18)───Ry(theta19)───Rz(theta20)───@───────────────────Rx(x5_0)───Rx(theta36)───Ry(theta37)───Rz(theta38)───@───────────────────Rx(x8_0)───Rx(theta54)───Ry(theta55)───Rz(theta56)───@───────────────────Rx(x11_0)───Rx(theta72)───Ry(theta73)───Rz(theta74)───@───────────────────Rx(x14_0)───Rx(theta90)────Ry(theta91)────Rz(theta92)────
#                                                          │                                                                        │                                                                        │                                                                        │                                                                         │
# (0, 1): ───H───Rx(theta3)────Ry(theta4)────Rz(theta5)────@───@───────────────Rx(x2_1)───Rx(theta21)───Ry(theta22)───Rz(theta23)───@───@───────────────Rx(x5_1)───Rx(theta39)───Ry(theta40)───Rz(theta41)───@───@───────────────Rx(x8_1)───Rx(theta57)───Ry(theta58)───Rz(theta59)───@───@───────────────Rx(x11_1)───Rx(theta75)───Ry(theta76)───Rz(theta77)───@───@───────────────Rx(x14_1)───Rx(theta93)────Ry(theta94)────Rz(theta95)────
#                                                              │                                                                        │                                                                        │                                                                        │                                                                         │
# (0, 2): ───H───Rx(theta6)────Ry(theta7)────Rz(theta8)────────@───@───────────Rx(x2_2)───Rx(theta24)───Ry(theta25)───Rz(theta26)───────@───@───────────Rx(x5_2)───Rx(theta42)───Ry(theta43)───Rz(theta44)───────@───@───────────Rx(x8_2)───Rx(theta60)───Ry(theta61)───Rz(theta62)───────@───@───────────Rx(x11_2)───Rx(theta78)───Ry(theta79)───Rz(theta80)───────@───@───────────Rx(x14_2)───Rx(theta96)────Ry(theta97)────Rz(theta98)────
#                                                                  │                                                                        │                                                                        │                                                                        │                                                                         │
# (0, 3): ───H───Rx(theta9)────Ry(theta10)───Rz(theta11)───────────@───@───────Rx(x2_3)───Rx(theta27)───Ry(theta28)───Rz(theta29)───────────@───@───────Rx(x5_3)───Rx(theta45)───Ry(theta46)───Rz(theta47)───────────@───@───────Rx(x8_3)───Rx(theta63)───Ry(theta64)───Rz(theta65)───────────@───@───────Rx(x11_3)───Rx(theta81)───Ry(theta82)───Rz(theta83)───────────@───@───────Rx(x14_3)───Rx(theta99)────Ry(theta100)───Rz(theta101)───
#                                                                      │                                                                        │                                                                        │                                                                        │                                                                         │
# (0, 4): ───H───Rx(theta12)───Ry(theta13)───Rz(theta14)───────────────@───@───Rx(x2_4)───Rx(theta30)───Ry(theta31)───Rz(theta32)───────────────@───@───Rx(x5_4)───Rx(theta48)───Ry(theta49)───Rz(theta50)───────────────@───@───Rx(x8_4)───Rx(theta66)───Ry(theta67)───Rz(theta68)───────────────@───@───Rx(x11_4)───Rx(theta84)───Ry(theta85)───Rz(theta86)───────────────@───@───Rx(x14_4)───Rx(theta102)───Ry(theta103)───Rz(theta104)───
#                                                                          │                                                                        │                                                                        │                                                                        │                                                                         │
# (0, 5): ───H───Rx(theta15)───Ry(theta16)───Rz(theta17)───────────────────@───Rx(x2_5)───Rx(theta33)───Ry(theta34)───Rz(theta35)───────────────────@───Rx(x5_5)───Rx(theta51)───Ry(theta52)───Rz(theta53)───────────────────@───Rx(x8_5)───Rx(theta69)───Ry(theta70)───Rz(theta71)───────────────────@───Rx(x11_5)───Rx(theta87)───Ry(theta88)───Rz(theta89)───────────────────@───Rx(x14_5)───Rx(theta105)───Ry(theta106)───Rz(theta107)───</pre>

# %%
from tensorflow.keras.optimizers import Adam
import gym
env_name = "Acrobot-v1"
env = gym.make(env_name)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n
# hidden_dim = 64

# device = torch.device("cpu")

actor = model

critic = ValueNet()  # 价值网络
# 广义优势估计（Generalized Advantage Estimation，GAE）
# gamma 是GAE的超参数
gamma = 0.98

# lmbda 也用来计算广义优势估
lmbda = 0.95

epochs = 4  # 一条序列的数据用来训练轮数 4
eps = 0.2  # 裁剪超参数
# actor_lr = 1e-3
# critic_lr = 1e-2  # 结合 量子电路后 这个变得重要了起来
# critic_lr = 1e-1  # 结合 量子电路后 这个变得重要了起来
critic_lr = 2.5e-4 #

optimizer_in = Adam(learning_rate=0.1, amsgrad=False, epsilon=1e-5)
optimizer_var = Adam(learning_rate=0.01, amsgrad=False, epsilon=1e-5)
optimizer_out = Adam(learning_rate=0.1, amsgrad=False, epsilon=1e-5)

# Assign the model parameters to each optimizer
w_in, w_var, w_out = 1, 0, 2

# critic_optimizer = Adam(learning_rate=critic_lr)
critic_optimizer = Adam(learning_rate=critic_lr, amsgrad=False, epsilon=1e-5)

# %%
from misc.utils import train

# %%
import numpy as np

state_bounds = np.array([1., 1., 1., 1., 12.567 , 28.274])
state_ub = state_bounds
state_lb = -1 * state_bounds

# %%
return_list = train(env_name, actor, critic, gamma, lmbda, eps, epochs,
          optimizer_in, optimizer_var, optimizer_out, critic_optimizer, -150.,
          critic_normalized=False, state_ub=state_ub, state_lb=state_lb, num_episodes=1000)
# Out:
# 当前迭代次数为：0, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：1, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：2, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：3, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：4, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：5, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：6, 当前奖励为：-448.0, 平均奖励为：-492.57142857142856
# 当前迭代次数为：7, 当前奖励为：-473.0, 平均奖励为：-490.125
# 当前迭代次数为：8, 当前奖励为：-500.0, 平均奖励为：-491.22222222222223
# 当前迭代次数为：9, 当前奖励为：-500.0, 平均奖励为：-492.1
# 当前迭代次数为：10, 当前奖励为：-500.0, 平均奖励为：-492.1
# 当前迭代次数为：11, 当前奖励为：-500.0, 平均奖励为：-492.1
# 当前迭代次数为：12, 当前奖励为：-500.0, 平均奖励为：-492.1
# 当前迭代次数为：13, 当前奖励为：-500.0, 平均奖励为：-492.1
# 当前迭代次数为：14, 当前奖励为：-500.0, 平均奖励为：-492.1
# 当前迭代次数为：15, 当前奖励为：-500.0, 平均奖励为：-492.1
# 当前迭代次数为：16, 当前奖励为：-500.0, 平均奖励为：-497.3
# 当前迭代次数为：17, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：18, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：19, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：20, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：21, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：22, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：23, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：24, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：25, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：26, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：27, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：28, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：29, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：30, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：31, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：32, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：33, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：34, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：35, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：36, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：37, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：38, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：39, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：40, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：41, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：42, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：43, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：44, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：45, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：46, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：47, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：48, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：49, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：50, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：51, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：52, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：53, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：54, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：55, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：56, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：57, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：58, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：59, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：60, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：61, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：62, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：63, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：64, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：65, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：66, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：67, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：68, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：69, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：70, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：71, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：72, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：73, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：74, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：75, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：76, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：77, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：78, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：79, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：80, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：81, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：82, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：83, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：84, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：85, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：86, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：87, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：88, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：89, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：90, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：91, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：92, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：93, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：94, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：95, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：96, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：97, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：98, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：99, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：100, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：101, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：102, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：103, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：104, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：105, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：106, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：107, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：108, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：109, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：110, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：111, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：112, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：113, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：114, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：115, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：116, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：117, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：118, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：119, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：120, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：121, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：122, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：123, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：124, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：125, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：126, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：127, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：128, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：129, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：130, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：131, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：132, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：133, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：134, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：135, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：136, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：137, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：138, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：139, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：140, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：141, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：142, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：143, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：144, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：145, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：146, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：147, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：148, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：149, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：150, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：151, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：152, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：153, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：154, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：155, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：156, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：157, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：158, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：159, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：160, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：161, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：162, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：163, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：164, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：165, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：166, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：167, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：168, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：169, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：170, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：171, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：172, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：173, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：174, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：175, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：176, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：177, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：178, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：179, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：180, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：181, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：182, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：183, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：184, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：185, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：186, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：187, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：188, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：189, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：190, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：191, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：192, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：193, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：194, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：195, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：196, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：197, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：198, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：199, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：200, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：201, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：202, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：203, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：204, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：205, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：206, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：207, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：208, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：209, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：210, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：211, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：212, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：213, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：214, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：215, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：216, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：217, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：218, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：219, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：220, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：221, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：222, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：223, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：224, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：225, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：226, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：227, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：228, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：229, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：230, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：231, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：232, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：233, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：234, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：235, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：236, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：237, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：238, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：239, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：240, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：241, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：242, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：243, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：244, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：245, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：246, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：247, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：248, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：249, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：250, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：251, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：252, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：253, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：254, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：255, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：256, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：257, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：258, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：259, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：260, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：261, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：262, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为：263, 当前奖励为：-500.0, 平均奖励为：-500.0
# 当前迭代次数为