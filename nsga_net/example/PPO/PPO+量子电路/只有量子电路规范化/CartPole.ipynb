# %%
import tensorflow as tf

using_gpu_index = 0 # 使用的 GPU 号码
gpu_list = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_virtual_device_configuration(
        gpu_list[using_gpu_index],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024 * 4)]
    )
# Out:
# 2023-10-15 18:40:59.237768: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 18:40:59.261996: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 18:40:59.262137: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
import cirq
import models.quantum_genotypes as genotypes

from models.quantum_models import generate_model_policy
from functools import reduce

env_name = "CartPole-v1"
qubits = cirq.GridQubit.rect(1, 4)
genotype = genotypes.ORI_TYPE_CP
n_actions = 2  # Number of actions in CartPole

ops = [cirq.Z(q) for q in qubits]
observables = [reduce((lambda x, y: x * y), ops)]  # Z_0*Z_1*Z_2*Z_3
# generate_model_policy(qubits, genotype, n_actions, beta, observables, env):
model = generate_model_policy(qubits, genotype, n_actions, 1., observables, env_name, using_H=True)
# Out:
# 2023-10-15 18:41:00.418638: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-15 18:41:00.419604: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 18:41:00.419730: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 18:41:00.419793: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 18:41:01.042576: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 18:41:01.042709: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 18:41:01.042773: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 18:41:01.042843: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4096 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# CartPole-v1

# %%
from models.value_net import ValueNet

# %%
from IPython.core.display import HTML
from models.quantum_models import generate_circuit

circuit, params, inputs = generate_circuit(qubits, genotype, using_H=True)
display(HTML(f"<pre>{circuit}</pre>"))
# Out:
# <pre>(0, 0): ───H───Rx(theta0)───Ry(theta1)────Rz(theta2)────@───────────Rx(x2_0)───Rx(theta12)───Ry(theta13)───Rz(theta14)───@───────────Rx(x5_0)───Rx(theta24)───Ry(theta25)───Rz(theta26)───@───────────Rx(x8_0)───Rx(theta36)───Ry(theta37)───Rz(theta38)───@───────────Rx(x11_0)───Rx(theta48)───Ry(theta49)───Rz(theta50)───@───────────Rx(x14_0)───Rx(theta60)───Ry(theta61)───Rz(theta62)───
#                                                         │                                                                │                                                                │                                                                │                                                                 │
# (0, 1): ───H───Rx(theta3)───Ry(theta4)────Rz(theta5)────@───@───────Rx(x2_1)───Rx(theta15)───Ry(theta16)───Rz(theta17)───@───@───────Rx(x5_1)───Rx(theta27)───Ry(theta28)───Rz(theta29)───@───@───────Rx(x8_1)───Rx(theta39)───Ry(theta40)───Rz(theta41)───@───@───────Rx(x11_1)───Rx(theta51)───Ry(theta52)───Rz(theta53)───@───@───────Rx(x14_1)───Rx(theta63)───Ry(theta64)───Rz(theta65)───
#                                                             │                                                                │                                                                │                                                                │                                                                 │
# (0, 2): ───H───Rx(theta6)───Ry(theta7)────Rz(theta8)────────@───@───Rx(x2_2)───Rx(theta18)───Ry(theta19)───Rz(theta20)───────@───@───Rx(x5_2)───Rx(theta30)───Ry(theta31)───Rz(theta32)───────@───@───Rx(x8_2)───Rx(theta42)───Ry(theta43)───Rz(theta44)───────@───@───Rx(x11_2)───Rx(theta54)───Ry(theta55)───Rz(theta56)───────@───@───Rx(x14_2)───Rx(theta66)───Ry(theta67)───Rz(theta68)───
#                                                                 │                                                                │                                                                │                                                                │                                                                 │
# (0, 3): ───H───Rx(theta9)───Ry(theta10)───Rz(theta11)───────────@───Rx(x2_3)───Rx(theta21)───Ry(theta22)───Rz(theta23)───────────@───Rx(x5_3)───Rx(theta33)───Ry(theta34)───Rz(theta35)───────────@───Rx(x8_3)───Rx(theta45)───Ry(theta46)───Rz(theta47)───────────@───Rx(x11_3)───Rx(theta57)───Ry(theta58)───Rz(theta59)───────────@───Rx(x14_3)───Rx(theta69)───Ry(theta70)───Rz(theta71)───</pre>

# %%
from tensorflow.keras.optimizers import Adam
import gym
env_name = "CartPole-v1"
env = gym.make(env_name)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n
# hidden_dim = 64

# device = torch.device("cpu")

actor = model

critic = ValueNet()  # 价值网络
# 广义优势估计（Generalized Advantage Estimation，GAE）
# gamma 是GAE的超参数
gamma = 0.98

# lmbda 也用来计算广义优势估
lmbda = 0.95

epochs = 10  # 一条序列的数据用来训练轮数 4
eps = 0.2  # 裁剪超参数
# actor_lr = 1e-3
critic_lr = 1e-2  # 结合 量子电路后 这个变得重要了起来
# critic_lr = 1e-1  # 结合 量子电路后 这个变得重要了起来
# critic_lr = 2.5e-4 #

# actor_optimizer = Adam(learning_rate=actor_lr)

optimizer_in = Adam(learning_rate=0.1, amsgrad=False, epsilon=1e-5)
optimizer_var = Adam(learning_rate=0.01, amsgrad=False, epsilon=1e-5)
optimizer_out = Adam(learning_rate=0.1, amsgrad=False, epsilon=1e-5)

# Assign the model parameters to each optimizer
w_in, w_var, w_out = 1, 0, 2

# critic_optimizer = Adam(learning_rate=critic_lr)
critic_optimizer = Adam(learning_rate=critic_lr, amsgrad=False, epsilon=1e-5)

# %%
from misc.utils import train

# %%
import numpy as np

state_bounds = np.array([2.4, 2.5, 0.21, 2.5])
state_ub = state_bounds
state_lb = -1 * state_bounds

# %%
return_list = train(env_name, actor, critic, gamma, lmbda, eps, epochs,
          optimizer_in, optimizer_var, optimizer_out, critic_optimizer, 500.,
          critic_normalized=False, state_ub=state_ub, state_lb=state_lb, num_episodes=1000)
# Out:
# 当前迭代次数为：0, 当前奖励为：29.0, 平均奖励为：29.0
# 当前迭代次数为：1, 当前奖励为：12.0, 平均奖励为：20.5
# 当前迭代次数为：2, 当前奖励为：12.0, 平均奖励为：17.666666666666668
# 当前迭代次数为：3, 当前奖励为：15.0, 平均奖励为：17.0
# 当前迭代次数为：4, 当前奖励为：9.0, 平均奖励为：15.4
# 当前迭代次数为：5, 当前奖励为：9.0, 平均奖励为：14.333333333333334
# 当前迭代次数为：6, 当前奖励为：10.0, 平均奖励为：13.714285714285714
# 当前迭代次数为：7, 当前奖励为：15.0, 平均奖励为：13.875
# 当前迭代次数为：8, 当前奖励为：16.0, 平均奖励为：14.11111111111111
# 当前迭代次数为：9, 当前奖励为：15.0, 平均奖励为：14.2
# 当前迭代次数为：10, 当前奖励为：15.0, 平均奖励为：12.8
# 当前迭代次数为：11, 当前奖励为：24.0, 平均奖励为：14.0
# 当前迭代次数为：12, 当前奖励为：26.0, 平均奖励为：15.4
# 当前迭代次数为：13, 当前奖励为：83.0, 平均奖励为：22.2
# 当前迭代次数为：14, 当前奖励为：84.0, 平均奖励为：29.7
# 当前迭代次数为：15, 当前奖励为：58.0, 平均奖励为：34.6
# 当前迭代次数为：16, 当前奖励为：111.0, 平均奖励为：44.7
# 当前迭代次数为：17, 当前奖励为：70.0, 平均奖励为：50.2
# 当前迭代次数为：18, 当前奖励为：79.0, 平均奖励为：56.5
# 当前迭代次数为：19, 当前奖励为：42.0, 平均奖励为：59.2
# 当前迭代次数为：20, 当前奖励为：70.0, 平均奖励为：64.7
# 当前迭代次数为：21, 当前奖励为：108.0, 平均奖励为：73.1
# 当前迭代次数为：22, 当前奖励为：77.0, 平均奖励为：78.2
# 当前迭代次数为：23, 当前奖励为：142.0, 平均奖励为：84.1
# 当前迭代次数为：24, 当前奖励为：148.0, 平均奖励为：90.5
# 当前迭代次数为：25, 当前奖励为：137.0, 平均奖励为：98.4
# 当前迭代次数为：26, 当前奖励为：157.0, 平均奖励为：103.0
# 当前迭代次数为：27, 当前奖励为：241.0, 平均奖励为：120.1
# 当前迭代次数为：28, 当前奖励为：196.0, 平均奖励为：131.8
# 当前迭代次数为：29, 当前奖励为：235.0, 平均奖励为：151.1
# 当前迭代次数为：30, 当前奖励为：500.0, 平均奖励为：194.1
# 当前迭代次数为：31, 当前奖励为：500.0, 平均奖励为：233.3
# 当前迭代次数为：32, 当前奖励为：112.0, 平均奖励为：236.8
# 当前迭代次数为：33, 当前奖励为：310.0, 平均奖励为：253.6
# 当前迭代次数为：34, 当前奖励为：368.0, 平均奖励为：275.6
# 当前迭代次数为：35, 当前奖励为：500.0, 平均奖励为：311.9
# 当前迭代次数为：36, 当前奖励为：500.0, 平均奖励为：346.2
# 当前迭代次数为：37, 当前奖励为：167.0, 平均奖励为：338.8
# 当前迭代次数为：38, 当前奖励为：407.0, 平均奖励为：359.9
# 当前迭代次数为：39, 当前奖励为：500.0, 平均奖励为：386.4
# 当前迭代次数为：40, 当前奖励为：415.0, 平均奖励为：377.9
# 当前迭代次数为：41, 当前奖励为：500.0, 平均奖励为：377.9
# 当前迭代次数为：42, 当前奖励为：500.0, 平均奖励为：416.7
# 当前迭代次数为：43, 当前奖励为：94.0, 平均奖励为：395.1
# 当前迭代次数为：44, 当前奖励为：500.0, 平均奖励为：408.3
# 当前迭代次数为：45, 当前奖励为：500.0, 平均奖励为：408.3
# 当前迭代次数为：46, 当前奖励为：35.0, 平均奖励为：361.8
# 当前迭代次数为：47, 当前奖励为：500.0, 平均奖励为：395.1
# 当前迭代次数为：48, 当前奖励为：10.0, 平均奖励为：355.4
# 当前迭代次数为：49, 当前奖励为：31.0, 平均奖励为：308.5
# 当前迭代次数为：50, 当前奖励为：15.0, 平均奖励为：268.5
# 当前迭代次数为：51, 当前奖励为：16.0, 平均奖励为：220.1
# 当前迭代次数为：52, 当前奖励为：22.0, 平均奖励为：172.3
# 当前迭代次数为：53, 当前奖励为：22.0, 平均奖励为：165.1
# 当前迭代次数为：54, 当前奖励为：32.0, 平均奖励为：118.3
# 当前迭代次数为：55, 当前奖励为：35.0, 平均奖励为：71.8
# 当前迭代次数为：56, 当前奖励为：30.0, 平均奖励为：71.3
# 当前迭代次数为：57, 当前奖励为：41.0, 平均奖励为：25.4
# 当前迭代次数为：58, 当前奖励为：129.0, 平均奖励为：37.3
# 当前迭代次数为：59, 当前奖励为：33.0, 平均奖励为：37.5
# 当前迭代次数为：60, 当前奖励为：18.0, 平均奖励为：37.8
# 当前迭代次数为：61, 当前奖励为：85.0, 平均奖励为：44.7
# 当前迭代次数为：62, 当前奖励为：34.0, 平均奖励为：45.9
# 当前迭代次数为：63, 当前奖励为：147.0, 平均奖励为：58.4
# 当前迭代次数为：64, 当前奖励为：34.0, 平均奖励为：58.6
# 当前迭代次数为：65, 当前奖励为：133.0, 平均奖励为：68.4
# 当前迭代次数为：66, 当前奖励为：99.0, 平均奖励为：75.3
# 当前迭代次数为：67, 当前奖励为：109.0, 平均奖励为：82.1
# 当前迭代次数为：68, 当前奖励为：107.0, 平均奖励为：79.9
# 当前迭代次数为：69, 当前奖励为：102.0, 平均奖励为：86.8
# 当前迭代次数为：70, 当前奖励为：152.0, 平均奖励为：100.2
# 当前迭代次数为：71, 当前奖励为：153.0, 平均奖励为：107.0
# 当前迭代次数为：72, 当前奖励为：157.0, 平均奖励为：119.3
# 当前迭代次数为：73, 当前奖励为：166.0, 平均奖励为：121.2
# 当前迭代次数为：74, 当前奖励为：150.0, 平均奖励为：132.8
# 当前迭代次数为：75, 当前奖励为：157.0, 平均奖励为：135.2
# 当前迭代次数为：76, 当前奖励为：325.0, 平均奖励为：157.8
# 当前迭代次数为：77, 当前奖励为：157.0, 平均奖励为：162.6
# 当前迭代次数为：78, 当前奖励为：212.0, 平均奖励为：173.1
# 当前迭代次数为：79, 当前奖励为：190.0, 平均奖励为：181.9
# 当前迭代次数为：80, 当前奖励为：265.0, 平均奖励为：193.2
# 当前迭代次数为：81, 当前奖励为：164.0, 平均奖励为：194.3
# 当前迭代次数为：82, 当前奖励为：243.0, 平均奖励为：202.9
# 当前迭代次数为：83, 当前奖励为：131.0, 平均奖励为：199.4
# 当前迭代次数为：84, 当前奖励为：265.0, 平均奖励为：210.9
# 当前迭代次数为：85, 当前奖励为：204.0, 平均奖励为：215.6
# 当前迭代次数为：86, 当前奖励为：175.0, 平均奖励为：200.6
# 当前迭代次数为：87, 当前奖励为：163.0, 平均奖励为：201.2
# 当前迭代次数为：88, 当前奖励为：221.0, 平均奖励为：202.1
# 当前迭代次数为：89, 当前奖励为：406.0, 平均奖励为：223.7
# 当前迭代次数为：90, 当前奖励为：278.0, 平均奖励为：225.0
# 当前迭代次数为：91, 当前奖励为：176.0, 平均奖励为：226.2
# 当前迭代次数为：92, 当前奖励为：203.0, 平均奖励为：222.2
# 当前迭代次数为：93, 当前奖励为：180.0, 平均奖励为：227.1
# 当前迭代次数为：94, 当前奖励为：145.0, 平均奖励为：215.1
# 当前迭代次数为：95, 当前奖励为：147.0, 平均奖励为：209.4
# 当前迭代次数为：96, 当前奖励为：143.0, 平均奖励为：206.2
# 当前迭代次数为：97, 当前奖励为：155.0, 平均奖励为：205.4
# 当前迭代次数为：98, 当前奖励为：140.0, 平均奖励为：197.3
# 当前迭代次数为：99, 当前奖励为：166.0, 平均奖励为：173.3
# 当前迭代次数为：100, 当前奖励为：204.0, 平均奖励为：165.9
# 当前迭代次数为：101, 当前奖励为：187.0, 平均奖励为：167.0
# 当前迭代次数为：102, 当前奖励为：182.0, 平均奖励为：164.9
# 当前迭代次数为：103, 当前奖励为：184.0, 平均奖励为：165.3
# 当前迭代次数为：104, 当前奖励为：169.0, 平均奖励为：167.7
# 当前迭代次数为：105, 当前奖励为：148.0, 平均奖励为：167.8
# 当前迭代次数为：106, 当前奖励为：194.0, 平均奖励为：172.9
# 当前迭代次数为：107, 当前奖励为：200.0, 平均奖励为：177.4
# 当前迭代次数为：108, 当前奖励为：212.0, 平均奖励为：184.6
# 当前迭代次数为：109, 当前奖励为：225.0, 平均奖励为：190.5
# 当前迭代次数为：110, 当前奖励为：190.0, 平均奖励为：189.1
# 当前迭代次数为：111, 当前奖励为：149.0, 平均奖励为：185.3
# 当前迭代次数为：112, 当前奖励为：165.0, 平均奖励为：183.6
# 当前迭代次数为：113, 当前奖励为：149.0, 平均奖励为：180.1
# 当前迭代次数为：114, 当前奖励为：125.0, 平均奖励为：175.7
# 当前迭代次数为：115, 当前奖励为：221.0, 平均奖励为：183.0
# 当前迭代次数为：116, 当前奖励为：109.0, 平均奖励为：174.5
# 当前迭代次数为：117, 当前奖励为：129.0, 平均奖励为：167.4
# 当前迭代次数为：118, 当前奖励为：213.0, 平均奖励为：167.5
# 当前迭代次数为：119, 当前奖励为：86.0, 平均奖励为：153.6
# 当前迭代次数为：120, 当前奖励为：198.0, 平均奖励为：154.4
# 当前迭代次数为：121, 当前奖励为：214.0, 平均奖励为：160.9
# 当前迭代次数为：122, 当前奖励为：289.0, 平均奖励为：173.3
# 当前迭代次数为：123, 当前奖励为：385.0, 平均奖励为：196.9
# 当前迭代次数为：124, 当前奖励为：405.0, 平均奖励为：224.9
# 当前迭代次数为：125, 当前奖励为：357.0, 平均奖励为：238.5
# 当前迭代次数为：126, 当前奖励为：386.0, 平均奖励为：266.2
# 当前迭代次数为：127, 当前奖励为：391.0, 平均奖励为：292.4
# 当前迭代次数为：128, 当前奖励为：260.0, 平均奖励为：297.1
# 当前迭代次数为：129, 当前奖励为：426.0, 平均奖励为：331.1
# 当前迭代次数为：130, 当前奖励为：500.0, 平均奖励为：361.3
# 当前迭代次数为：131, 当前奖励为：500.0, 平均奖励为：389.9
# 当前迭代次数为：132, 当前奖励为：500.0, 平均奖励为：411.0
# 当前迭代次数为：133, 当前奖励为：14.0, 平均奖励为：373.9
# 当前迭代次数为：134, 当前奖励为：385.0, 平均奖励为：371.9
# 当前迭代次数为：135, 当前奖励为：365.0, 平均奖励为：372.7
# 当前迭代次数为：136, 当前奖励为：9.0, 平均奖励为：335.0
# 当前迭代次数为：137, 当前奖励为：13.0, 平均奖励为：297.2
# 当前迭代次数为：138, 当前奖励为：13.0, 平均奖励为：272.5
# 当前迭代次数为：139, 当前奖励为：24.0, 平均奖励为：232.3
# 当前迭代次数为：140, 当前奖励为：54.0, 平均奖励为：187.7
# 当前迭代次数为：141, 当前奖励为：13.0, 平均奖励为：139.0
# 当前迭代次数为：142, 当前奖励为：23.0, 平均奖励为：91.3
# 当前迭代次数为：143, 当前奖励为：16.0, 平均奖励为：91.5
# 当前迭代次数为：144, 当前奖励为：62.0, 平均奖励为：59.2
# 当前迭代次数为：145, 当前奖励为：25.0, 平均奖励为：25.2
# 当前迭代次数为：146, 当前奖励为：151.0, 平均奖励为：39.4
# 当前迭代次数为：147, 当前奖励为：41.0, 平均奖励为：42.2
# 当前迭代次数为：148, 当前奖励为：135.0, 平均奖励为：54.4
# 当前迭代次数为：149, 当前奖励为：150.0, 平均奖励为：67.0
# 当前迭代次数为：150, 当前奖励为：153.0, 平均奖励为：76.9
# 当前迭代次数为：151, 当前奖励为：223.0, 平均奖励为：97.9
# 当前迭代次数为：152, 当前奖励为：287.0, 平均奖励为：124.3
# 当前迭代次数为：153, 当前奖励为：329.0, 平均奖励为：155.6
# 当前迭代次数为：154, 当前奖励为：239.0, 平均奖励为：173.3
# 当前迭代次数为：155, 当前奖励为：75.0, 平均奖励为：178.3
# 当前迭代次数为：156, 当前奖励为：235.0, 平均奖励为：186.7
# 当前迭代次数为：157, 当前奖励为：79.0, 平均奖励为：190.5
# 当前迭代次数为：158, 当前奖励为：87.0, 平均奖励为：185.7
# 当前迭代次数为：159, 当前奖励为：95.0, 平均奖励为：180.2
# 当前迭代次数为：160, 当前奖励为：119.0, 平均奖励为：176.8
# 当前迭代次数为：161, 当前奖励为：280.0, 平均奖励为：182.5
# 当前迭代次数为：162, 当前奖励为：257.0, 平均奖励为：179.5
# 当前迭代次数为：163, 当前奖励为：287.0, 平均奖励为：175.3
# 当前迭代次数为：164, 当前奖励为：264.0, 平均奖励为：177.8
# 当前迭代次数为：165, 当前奖励为：382.0, 平均奖励为：208.5
# 当前迭代次数为：166, 当前奖励为：271.0, 平均奖励为：212.1
# 当前迭代次数为：167, 当前奖励为：365.0, 平均奖励为：240.7
# 当前迭代次数为：168, 当前奖励为：421.0, 平均奖励为：274.1
# 当前迭代次数为：169, 当前奖励为：474.0, 平均奖励为：312.0
# 当前迭代次数为：170, 当前奖励为：138.0, 平均奖励为：313.9
# 当前迭代次数为：171, 当前奖励为：101.0, 平均奖励为：296.0
# 当前迭代次数为：172, 当前奖励为：72.0, 平均奖励为：277.5
# 当前迭代次数为：173, 当前奖励为：124.0, 平均奖励为：261.2
# 当前迭代次数为：174, 当前奖励为：272.0, 平均奖励为：262.0
# 当前迭代次数为：175, 当前奖励为：250.0, 平均奖励为：248.8
# 当前迭代次数为：176, 当前奖励为：377.0, 平均奖励为：259.4
# 当前迭代次数为：177, 当前奖励为：260.0, 平均奖励为：248.9
# 当前迭代次数为：178, 当前奖励为：464.0, 平均奖励为：253.2
# 当前迭代次数为：179, 当前奖励为：301.0, 平均奖励为：235.9
# 当前迭代次数为：180, 当前奖励为：122.0, 平均奖励为：234.3
# 当前迭代次数为：181, 当前奖励为：102.0, 平均奖励为：234.4
# 当前迭代次数为：182, 当前奖励为：182.0, 平均奖励为：245.4
# 当前迭代次数为：183, 当前奖励为：284.0, 平均奖励为：261.4
# 当前迭代次数为：184, 当前奖励为：500.0, 平均奖励为：284.2
# 当前迭代次数为：185, 当前奖励为：499.0, 平均奖励为：309.1
# 当前迭代次数为：186, 当前奖励为：139.0, 平均奖励为：285.3
# 当前迭代次数为：187, 当前奖励为：47.0, 平均奖励为：264.0
# 当前迭代次数为：188, 当前奖励为：236.0, 平均奖励为：241.2
# 当前迭代次数为：189, 当前奖励为：194.0, 平均奖励为：230.5
# 当前迭代次数为：190, 当前奖励为：212.0, 平均奖励为：239.5
# 当前迭代次数为：191, 当前奖励为：191.0, 平均奖励为：248.4
# 当前迭代次数为：192, 当前奖励为：267.0, 平均奖励为：256.9
# 当前迭代次数为：193, 当前奖励为：306.0, 平均奖励为：259.1
# 当前迭代次数为：194, 当前奖励为：307.0, 平均奖励为：239.8
# 当前迭代次数为：195, 当前奖励为：211.0, 平均奖励为：211.0
# 当前迭代次数为：196, 当前奖励为：232.0, 平均奖励为：220.3
# 当前迭代次数为：197, 当前奖励为：153.0, 平均奖励为：230.9
# 当前迭代次数为：198, 当前奖励为：177.0, 平均奖励为：225.0
# 当前迭代次数为：199, 当前奖励为：70.0, 平均奖励为：212.6
# 当前迭代次数为：200, 当前奖励为：61.0, 平均奖励为：197.5
# 当前迭代次数为：201, 当前奖励为：132.0, 平均奖励为：191.6
# 当前迭代次数为：202, 当前奖励为：201.0, 平均奖励为：185.0
# 当前迭代次数为：203, 当前奖励为：77.0, 平均奖励为：162.1
# 当前迭代次数为：204, 当前奖励为：104.0, 平均奖励为：141.8
# 当前迭代次数为：205, 当前奖励为：106.0, 平均奖励为：131.3
# 当前迭代次数为：206, 当前奖励为：89.0, 平均奖励为：117.0
# 当前迭代次数为：207, 当前奖励为：154.0, 平均奖励为：117.1
# 当前迭代次数为：208, 当前奖励为：123.0, 平均奖励为：111.7
# 当前迭代次数为：209, 当前奖励为：127.0, 平均奖励为：117.4
# 当前迭代次数为：210, 当前奖励为：114.0, 平均奖励为：122.7
# 当前迭代次数为：211, 当前奖励为：143.0, 平均奖励为：123.8
# 当前迭代次数为：212, 当前奖励为：107.0, 平均奖励为：114.4
# 当前迭代次数为：213, 当前奖励为：163.0, 平均奖励为：123.0
# 当前迭代次数为：214, 当前奖励为：179.0, 平均奖励为：130.5
# 当前迭代次数为：215, 当前奖励为：11.0, 平均奖励为：121.0
# 当前迭代次数为：216, 当前奖励为：89.0, 平均奖励为：121.0
# 当前迭代次数为：217, 当前奖励为：115.0, 平均奖励为：117.1
# 当前迭代次数为：218, 当前奖励为：166.0, 平均奖励为：121.4
# 当前迭代次数为：219, 当前奖励为：125.0, 平均奖励为：121.2
# 当前迭代次数为：220, 当前奖励为：73.0, 平均奖励为：117.1
# 当前迭代次数为：221, 当前奖励为：134.0, 平均奖励为：116.2
# 当前迭代次数为：222, 当前奖励为：96.0, 平均奖励为：115.1
# 当前迭代次数为：223, 当前奖励为：75.0, 平均奖励为：106.3
# 当前迭代次数为：224, 当前奖励为：43.0, 平均奖励为：92.7
# 当前迭代次数为：225, 当前奖励为：129.0, 平均奖励为：104.5
# 当前迭代次数为：226, 当前奖励为：35.0, 平均奖励为：99.1
# 当前迭代次数为：227, 当前奖励为：97.0, 平均奖励为：97.3
# 当前迭代次数为：228, 当前奖励为：124.0, 平均奖励为：93.1
# 当前迭代次数为：229, 当前奖励为：129.0, 平均奖励为：93.5
# 当前迭代次数为：230, 当前奖励为：127.0, 平均奖励为：98.9
# 当前迭代次数为：231, 当前奖励为：143.0, 平均奖励为：99.8
# 当前迭代次数为：232, 当前奖励为：74.0, 平均奖励为：97.6
# 当前迭代次数为：233, 当前奖励为：135.0, 平均奖励为：103.6
# 当前迭代次数为：234, 当前奖励为：129.0, 平均奖励为：112.2
# 当前迭代次数为：235, 当前奖励为：40.0, 平均奖励为：103.3
# 当前迭代次数为：236, 当前奖励为：16.0, 平均奖励为：101.4
# 当前迭代次数为：237, 当前奖励为：28.0, 平均奖励为：94.5
# 当前迭代次数为：238, 当前奖励为：36.0, 平均奖励为：85.7
# 当前迭代次数为：239, 当前奖励为：39.0, 平均奖励为：76.7
# 当前迭代次数为：240, 当前奖励为：329.0, 平均奖励为：96.9
# 当前迭代次数为：241, 当前奖励为：81.0, 平均奖励为：90.7
# 当前迭代次数为：242, 当前奖励为：114.0, 平均奖励为：94.7
# 当前迭代次数为：243, 当前奖励为：130.0, 平均奖励为：94.2
# 当前迭代次数为：244, 当前奖励为：203.0, 平均奖励为：101.6
# 当前迭代次数为：245, 当前奖励为：154.0, 平均奖励为：113.0
# 当前迭代次数为：246, 当前奖励为：195.0, 平均奖励为：130.9
# 当前迭代次数为：247, 当前奖励为：379.0, 平均奖励为：166.0
# 当前迭代次数为：248, 当前奖励为：203.0, 平均奖励为：182.7
# 当前迭代次数为：249, 当前奖励为：90.0, 平均奖励为：187.8
# 当前迭代次数为：250, 当前奖励为：173.0, 平均奖励为：172.2
# 当前迭代次数为：251, 当前奖励为：37.0, 平均奖励为：167.8
# 当前迭代次数为：252, 当前奖励为：85.0, 平均奖励为：164.9
# 当前迭代次数为：253, 当前奖励为：67.0, 平均奖励为：158.6
# 当前迭代次数为：254, 当前奖励为：309.0, 平均奖励为：169.2
# 当前迭代次数为：255, 当前奖励为：232.0, 平均奖励为：177.0
# 当前迭代次数为：256, 当前奖励为：500.0, 平均奖励为：207.5
# 当前迭代次数为：257, 当前奖励为：275.0, 平均奖励为：197.1
# 当前迭代次数为：258, 当前奖励为：471.0, 平均奖励为：223.9
# 当前迭代次数为：259, 当前奖励为：500.0, 平均奖励为：264.9
# 当前迭代次数为：260, 当前奖励为：500.0, 平均奖励为：297.6
# 当前迭代次数为：261, 当前奖励为：32.0, 平均奖励为：297.1
# 当前迭代次数为：262, 当前奖励为：44.0, 平均奖励为：293.0
# 当前迭代次数为：263, 当前奖励为：93.0, 平均奖励为：295.6
# 当前迭代次数为：264, 当前奖励为：27.0, 平均奖励为：267.4
# 当前迭代次数为：265, 当前奖励为：33.0, 平均奖励为：247.5
# 当前迭代次数为：266, 当前奖励为：56.0, 平均奖励为：203.1
# 当前迭代次数为：267, 当前奖励为：156.0, 平均奖励为：191.2
# 当前迭代次数为：268, 当前奖励为：124.0, 平均奖励为：156.5
# 当前迭代次数为：269, 当前奖励为：161.0, 平均奖励为：122.6
# 当前迭代次数为：270, 当前奖励为：153.0, 平均奖励为：87.9
# 当前迭代次数为：271, 当前奖励为：129.0, 平均奖励为：97.6
# 当前迭代次数为：272, 当前奖励为：130.0, 平均奖励为：106.2
# 当前迭代次数为：273, 当前奖励为：199.0, 平均奖励为：116.8
# 当前迭代次数为：274, 当前奖励为：50.0, 平均奖励为：119.1
# 当前迭代次数为：275, 当前奖励为：39.0, 平均奖励为：119.7
# 当前迭代次数为：276, 当前奖励为：234.0, 平均奖励为：137.5
# 当前迭代次数为：277, 当前奖励为：205.0, 平均奖励为：142.4
# 当前迭代次数为：278, 当前奖励为：20.0, 平均奖励为：132.0
# 当前迭代次数为：279, 当前奖励为：82.0, 平均奖励为：124.1
# 当前迭代次数为：280, 当前奖励为：303.0, 平均奖励为：139.1
# 当前迭代次数为：281, 当前奖励为：21.0, 平均奖励为：128.3
# 当前迭代次数为：282, 当前奖励为：97.0, 平均奖励为：125.0
# 当前迭代次数为：283, 当前奖励为：114.0, 平均奖励为：116.5
# 当前迭代次数为：284, 当前奖励为：150.0, 平均奖励为：126.5
# 当前迭代次数为：285, 当前奖励为：244.0, 平均奖励为：147.0
# 当前迭代次数为：286, 当前奖励为：192.0, 平均奖励为：142.8
# 当前迭代次数为：287, 当前奖励为：236.0, 平均奖励为：145.9
# 当前迭代次数为：288, 当前奖励为：500.0, 平均奖励为：193.9
# 当前迭代次数为：289, 当前奖励为：500.0, 平均奖励为：235.7
# 当前迭代次数为：290, 当前奖励为：500.0, 平均奖励为：255.4
# 当前迭代次数为：291, 当前奖励为：500.0, 平均奖励为：303.3
# 当前迭代次数为：292, 当前奖励为：500.0, 平均奖励为：343.6
# 当前迭代次数为：293, 当前奖励为：427.0, 平均奖励为：374.9
# 当前迭代次数为：294, 当前奖励为：455.0, 平均奖励为：405.4
# 当前迭代次数为：295, 当前奖励为：500.0, 平均奖励为：431.0
# 当前迭代次数为：296, 当前奖励为：500.0, 平均奖励为：461.8
# 当前迭代次数为：297, 当前奖励为：500.0, 平均奖励为：488.2
# 当前迭代次数为：298, 当前奖励为：126.0, 平均奖励为：450.8
# 当前迭代次数为：299, 当前奖励为：401.0, 平均奖励为：440.9
# 当前迭代次数为：300, 当前奖励为：500.0, 平均奖励为：440.9
# 当前迭代次数为：301, 当前奖励为：500.0, 平均奖励为：440.9
# 当前迭代次数为：302, 当前奖励为：500.0, 平均奖励为：440.9
# 当前迭代次数为：303, 当前奖励为：459.0, 平均奖励为：444.1
# 当前迭代次数为：304, 当前奖励为：500.0, 平均奖励为：448.6
# 当前迭代次数为：305, 当前奖励为：500.0, 平均奖励为：448.6
# 当前迭代次数为：306, 当前奖励为：500.0, 平均奖励为：448.6
# 当前迭代次数为：307, 当前奖励为：500.0, 平均奖励为：448.6
# 当前迭代次数为：308, 当前奖励为：500.0, 平均奖励为：486.0
# 当前迭代次数为：309, 当前奖励为：500.0, 平均奖励为：495.9
# 当前迭代次数为：310, 当前奖励为：500.0, 平均奖励为：495.9
# 当前迭代次数为：311, 当前奖励为：500.0, 平均奖励为：495.9
# 当前迭代次数为：312, 当前奖励为：500.0, 平均奖励为：495.9
# 当前迭代次数为：313, 当前奖励为：500.0, 平均奖励为：500.0

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(return_list)
plt.xlabel('Epsiode')
plt.ylabel('Collected rewards')
plt.show()

# %%
import pandas as pd

# 创建一个DataFrame对象
df = pd.DataFrame({'return_list': return_list})

# 将DataFrame保存到CSV文件
df.to_csv('../../../../results/example/PPO/PPO+量子电路/只有量子电路规范化/return_list_CP', index=False)  # 可以指定文件名和是否包括行索引
actor.save_weights('../../../../results/example/PPO/PPO+量子电路/只有量子电路规范化/weights_CP_ACTOR_NO_amsgrad.h5')
critic.save_weights('../../../../results/example/PPO/PPO+量子电路/只有量子电路规范化/weights_CP_CRITIC_NO_amsgrad.h5')
