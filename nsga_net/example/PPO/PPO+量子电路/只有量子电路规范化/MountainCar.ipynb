# %%
import tensorflow as tf

using_gpu_index = 0 # 使用的 GPU 号码
gpu_list = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_virtual_device_configuration(
        gpu_list[using_gpu_index],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024 * 4)]
    )
# Out:
# 2023-10-15 16:23:32.407789: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 16:23:32.412653: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 16:23:32.412785: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
import cirq
import models.quantum_genotypes as genotypes

from models.quantum_models import generate_model_policy
from functools import reduce
env_name = "MountainCar-v0"

genotype = genotypes.ORI_TYPE_MC

n_qubits = 2  # Dimension of the state vectors in CartPole
# n_layers = 6  # Number of layers in the PQC
n_actions = 3  # Number of actions in CartPole

qubits = cirq.GridQubit.rect(1, n_qubits)
ops = [cirq.Z(q) for q in qubits]
observables = [cirq.Z(qubits[0]), reduce((lambda x, y: x * y), ops), cirq.Z(qubits[1])]  # Z_0*Z_1*Z_2*Z_3


# generate_model_policy(qubits, genotype, n_actions, beta, observables, env):
model = generate_model_policy(qubits, genotype, n_actions, 1.5, observables, env_name, using_H=True)
# Out:
# 2023-10-15 16:23:33.427479: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-15 16:23:33.428331: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 16:23:33.428460: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 16:23:33.428533: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 16:23:33.737669: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 16:23:33.737802: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 16:23:33.737865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 16:23:33.737932: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4096 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# MountainCar-v0

# %%
from models.value_net import ValueNet

# %%
from IPython.core.display import HTML
from models.quantum_models import generate_circuit

circuit, params, inputs = generate_circuit(qubits, genotype, using_H=True)
display(HTML(f"<pre>{circuit}</pre>"))
# Out:
# <pre>(0, 0): ───H───Rx(theta0)───Ry(theta1)───Rz(theta2)───@───Rx(x2_0)───Rx(theta6)───Ry(theta7)────Rz(theta8)────@───Rx(x5_0)───Rx(theta12)───Ry(theta13)───Rz(theta14)───@───Rx(x8_0)───Rx(theta18)───Ry(theta19)───Rz(theta20)───@───Rx(x11_0)───Rx(theta24)───Ry(theta25)───Rz(theta26)───@───Rx(x14_0)───Rx(theta30)───Ry(theta31)───Rz(theta32)───Rx(x16_0)───@───Rx(theta36)───Ry(theta37)───Rz(theta38)───
#                                                       │                                                       │                                                        │                                                        │                                                         │                                                                     │
# (0, 1): ───H───Rx(theta3)───Ry(theta4)───Rz(theta5)───@───Rx(x2_1)───Rx(theta9)───Ry(theta10)───Rz(theta11)───@───Rx(x5_1)───Rx(theta15)───Ry(theta16)───Rz(theta17)───@───Rx(x8_1)───Rx(theta21)───Ry(theta22)───Rz(theta23)───@───Rx(x11_1)───Rx(theta27)───Ry(theta28)───Rz(theta29)───@───Rx(x14_1)───Rx(theta33)───Ry(theta34)───Rz(theta35)───Rx(x16_1)───@───Rx(theta39)───Ry(theta40)───Rz(theta41)───</pre>

# %%
from tensorflow.keras.optimizers import Adam

# hidden_dim = 64

# device = torch.device("cpu")

actor = model

critic = ValueNet()  # 价值网络
# 广义优势估计（Generalized Advantage Estimation，GAE）
# gamma 是GAE的超参数
gamma = 0.98

# lmbda 也用来计算广义优势估
lmbda = 0.95

epochs = 10  # 一条序列的数据用来训练轮数 4
eps = 0.2  # 裁剪超参数
# actor_lr = 1e-3
critic_lr = 1e-2  # 结合 量子电路后 这个变得重要了起来
# critic_lr = 1e-1  # 结合 量子电路后 这个变得重要了起来
# critic_lr = 1e-3  # 结合 量子电路后 这个变得重要了起来
# critic_lr = 2.5e-4 #

# actor_optimizer = Adam(learning_rate=actor_lr)

optimizer_in = Adam(learning_rate=0.01, epsilon=1e-5, amsgrad=False)
optimizer_var = Adam(learning_rate=0.01, epsilon=1e-5, amsgrad=False)
optimizer_out = Adam(learning_rate=0.1, epsilon=1e-5, amsgrad=False)

# Assign the model parameters to each optimizer
# w_in, w_var, w_out = 1, 0, 2

# critic_optimizer = Adam(learning_rate=critic_lr)
# critic_optimizer = Adam(learning_rate=critic_lr, amsgrad=True)  # 这个不知道 似乎作用有限
critic_optimizer = Adam(learning_rate=critic_lr, epsilon=1e-5, amsgrad=False)  # 全FALSE mountain car 可以收敛

# %%
from misc.utils import train
import numpy as np

state_ub = np.array([0.6, 0.07])
state_lb = np.array([-1.2, -0.07])

# %%
return_list = train(env_name, actor, critic, gamma, lmbda, eps, epochs,
          optimizer_in, optimizer_var, optimizer_out, critic_optimizer, -100.,
          critic_normalized=False, state_ub=state_ub, state_lb=state_lb, num_episodes=1000)
# Out:
# 当前迭代次数为：0, 当前奖励为：-178.53405604303273, 平均奖励为：-178.53405604303273
# 当前迭代次数为：1, 当前奖励为：-176.99024191427824, 平均奖励为：-177.7621489786555
# 当前迭代次数为：2, 当前奖励为：-168.49650294841152, 平均奖励为：-174.6736003019075
# 当前迭代次数为：3, 当前奖励为：-171.57658685884988, 平均奖励为：-173.89934694114308
# 当前迭代次数为：4, 当前奖励为：-140.23727026579945, 平均奖励为：-167.16693160607434
# 当前迭代次数为：5, 当前奖励为：-158.54942277213854, 平均奖励为：-165.73068013375172
# 当前迭代次数为：6, 当前奖励为：-178.16825649183923, 平均奖励为：-167.50747675633565
# 当前迭代次数为：7, 当前奖励为：-178.96238970829245, 平均奖励为：-168.93934087533026
# 当前迭代次数为：8, 当前奖励为：-171.47676236613393, 平均奖励为：-169.22127659653066
# 当前迭代次数为：9, 当前奖励为：-178.4760544521874, 平均奖励为：-170.14675438209633
# 当前迭代次数为：10, 当前奖励为：-170.0900325066666, 平均奖励为：-169.30235202845972
# 当前迭代次数为：11, 当前奖励为：-173.9348267824525, 平均奖励为：-168.99681051527716
# 当前迭代次数为：12, 当前奖励为：-158.25141877005936, 平均奖励为：-167.97230209744194
# 当前迭代次数为：13, 当前奖励为：-179.04417195096653, 平均奖励为：-168.7190606066536
# 当前迭代次数为：14, 当前奖励为：-178.32570525554198, 平均奖励为：-172.52790410562787
# 当前迭代次数为：15, 当前奖励为：-178.01917224725145, 平均奖励为：-174.47487905313912
# 当前迭代次数为：16, 当前奖励为：-173.12149854266133, 平均奖励为：-173.97020325822137
# 当前迭代次数为：17, 当前奖励为：-173.99849518456364, 平均奖励为：-173.47381380584847
# 当前迭代次数为：18, 当前奖励为：-179.13010039030053, 平均奖励为：-174.2391476082651
# 当前迭代次数为：19, 当前奖励为：-177.6209927258189, 平均奖励为：-174.15364143562826
# 当前迭代次数为：20, 当前奖励为：-179.14106951642788, 平均奖励为：-175.05874513660441
# 当前迭代次数为：21, 当前奖励为：-172.19032219908706, 平均奖励为：-174.88429467826785
# 当前迭代次数为：22, 当前奖励为：-169.48926621860898, 平均奖励为：-176.0080794231228
# 当前迭代次数为：23, 当前奖励为：-177.65945214198388, 平均奖励为：-175.86960744222455
# 当前迭代次数为：24, 当前奖励为：-173.51191476249107, 平均奖励为：-175.38822839291947
# 当前迭代次数为：25, 当前奖励为：-177.81450800974565, 平均奖励为：-175.3677619691689
# 当前迭代次数为：26, 当前奖励为：-154.44438386282675, 平均奖励为：-173.50005050118543
# 当前迭代次数为：27, 当前奖励为：-176.73108019618962, 平均奖励为：-173.77330900234804
# 当前迭代次数为：28, 当前奖励为：-143.24109113425652, 平均奖励为：-170.18440807674364
# 当前迭代次数为：29, 当前奖励为：-173.53021119041156, 平均奖励为：-169.77532992320292
# 当前迭代次数为：30, 当前奖励为：-148.05830519511608, 平均奖励为：-166.66705349107173
# 当前迭代次数为：31, 当前奖励为：-105.08680116043111, 平均奖励为：-159.95670138720612
# 当前迭代次数为：32, 当前奖励为：-169.3993812452277, 平均奖励为：-159.947712889868
# 当前迭代次数为：33, 当前奖励为：-120.97184410647397, 平均奖励为：-154.27895208631702
# 当前迭代次数为：34, 当前奖励为：-143.51361056945802, 平均奖励为：-151.2791216670137
# 当前迭代次数为：35, 当前奖励为：-144.907336342533, 平均奖励为：-147.98840450029243
# 当前迭代次数为：36, 当前奖励为：-150.7756998021165, 平均奖励为：-147.6215360942214
# 当前迭代次数为：37, 当前奖励为：-118.96751124777211, 平均奖励为：-141.84517919937966
# 当前迭代次数为：38, 当前奖励为：-122.0255571882642, 平均奖励为：-139.7236258047804
# 当前迭代次数为：39, 当前奖励为：-120.74246349213048, 平均奖励为：-134.4448510349523
# 当前迭代次数为：40, 当前奖励为：-169.9821463147801, 平均奖励为：-136.63723514691873
# 当前迭代次数为：41, 当前奖励为：-136.4346452065108, 平均奖励为：-139.77201955152668
# 当前迭代次数为：42, 当前奖励为：-121.73086556737549, 平均奖励为：-135.00516798374147
# 当前迭代次数为：43, 当前奖励为：-108.90405751107821, 平均奖励为：-133.79838932420188
# 当前迭代次数为：44, 当前奖励为：-103.94180263626853, 平均奖励为：-129.84120853088294
# 当前迭代次数为：45, 当前奖励为：-121.72184087210857, 平均奖励为：-127.52265898384049
# 当前迭代次数为：46, 当前奖励为：-139.89542830591014, 平均奖励为：-126.43463183421986
# 当前迭代次数为：47, 当前奖励为：-111.5726675114942, 平均奖励为：-125.69514746059208
# 当前迭代次数为：48, 当前奖励为：-109.60476114038183, 平均奖励为：-124.45306785580385
# 当前迭代次数为：49, 当前奖励为：-140.94918360465704, 平均奖励为：-126.4737398670565
# 当前迭代次数为：50, 当前奖励为：-107.39151306508926, 平均奖励为：-120.21467654208739
# 当前迭代次数为：51, 当前奖励为：-108.08517151806944, 平均奖励为：-117.37972917324328
# 当前迭代次数为：52, 当前奖励为：-104.52780407722447, 平均奖励为：-115.65942302422818
# 当前迭代次数为：53, 当前奖励为：-103.6150885318368, 平均奖励为：-115.13052612630403
# 当前迭代次数为：54, 当前奖励为：-109.702351968222, 平均奖励为：-115.70658105949937
# 当前迭代次数为：55, 当前奖励为：-110.16254074239309, 平均奖励为：-114.55065104652783
# 当前迭代次数为：56, 当前奖励为：-155.7719931465687, 平均奖励为：-116.13830753059369
# 当前迭代次数为：57, 当前奖励为：-116.60636188585705, 平均奖励为：-116.64167696802997
# 当前迭代次数为：58, 当前奖励为：-110.25570176282164, 平均奖励为：-116.70677103027394
# 当前迭代次数为：59, 当前奖励为：-125.3479531836604, 平均奖励为：-115.14664798817428
# 当前迭代次数为：60, 当前奖励为：-111.73491144727073, 平均奖励为：-115.58098782639243
# 当前迭代次数为：61, 当前奖励为：-120.21712601656776, 平均奖励为：-116.79418327624225
# 当前迭代次数为：62, 当前奖励为：-111.30669070191477, 平均奖励为：-117.4720719387113
# 当前迭代次数为：63, 当前奖励为：-122.91168037298792, 平均奖励为：-119.40173112282642
# 当前迭代次数为：64, 当前奖励为：-147.7096735463557, 平均奖励为：-123.20246328063976
# 当前迭代次数为：65, 当前奖励为：-154.9549072820834, 平均奖励为：-127.68169993460882
# 当前迭代次数为：66, 当前奖励为：-148.61150698827183, 平均奖励为：-126.96565131877912
# 当前迭代次数为：67, 当前奖励为：-129.15428191029645, 平均奖励为：-128.22044332122306
# 当前迭代次数为：68, 当前奖励为：-148.50592152141118, 平均奖励为：-132.04546529708202
# 当前迭代次数为：69, 当前奖励为：-144.45017413768264, 平均奖励为：-133.95568739248424
# 当前迭代次数为：70, 当前奖励为：-129.18280173641188, 平均奖励为：-135.70047642139835
# 当前迭代次数为：71, 当前奖励为：-141.9084162510496, 平均奖励为：-137.86960544484654
# 当前迭代次数为：72, 当前奖励为：-132.22538784388732, 平均奖励为：-139.9614751590438
# 当前迭代次数为：73, 当前奖励为：-142.35011254695698, 平均奖励为：-141.9053183764407
# 当前迭代次数为：74, 当前奖励为：-123.52152956493983, 平均奖励为：-139.4865039782991
# 当前迭代次数为：75, 当前奖励为：-118.01804571329916, 平均奖励为：-135.7928178214207
# 当前迭代次数为：76, 当前奖励为：-114.40890411944774, 平均奖励为：-132.3725575345383
# 当前迭代次数为：77, 当前奖励为：-168.62514815864793, 平均奖励为：-136.31964415937344
# 当前迭代次数为：78, 当前奖励为：-125.44037735268289, 平均奖励为：-134.0130897425006
# 当前迭代次数为：79, 当前奖励为：-126.6493142853863, 平均奖励为：-132.23300375727098
# 当前迭代次数为：80, 当前奖励为：-156.1328310010588, 平均奖励为：-134.92800668373565
# 当前迭代次数为：81, 当前奖励为：-122.88735784296642, 平均奖励为：-133.02590084292734
# 当前迭代次数为：82, 当前奖励为：-124.23094965132438, 平均奖励为：-132.22645702367103
# 当前迭代次数为：83, 当前奖励为：-142.57704549942318, 平均奖励为：-132.24915031891766
# 当前迭代次数为：84, 当前奖励为：-119.09771259854928, 平均奖励为：-131.80676862227864
# 当前迭代次数为：85, 当前奖励为：-113.6658164867367, 平均奖励为：-131.37154569962237
# 当前迭代次数为：86, 当前奖励为：-104.13468307521072, 平均奖励为：-130.34412359519865
# 当前迭代次数为：87, 当前奖励为：-127.65233547104273, 平均奖励为：-126.24684232643816
# 当前迭代次数为：88, 当前奖励为：-120.02901879604582, 平均奖励为：-125.70570647077443
# 当前迭代次数为：89, 当前奖励为：-114.48822832829494, 平均奖励为：-124.4895978750653
# 当前迭代次数为：90, 当前奖励为：-128.8927159855684, 平均奖励为：-121.76558637351627
# 当前迭代次数为：91, 当前奖励为：-128.1294522674382, 平均奖励为：-122.28979581596343
# 当前迭代次数为：92, 当前奖励为：-117.79379665149936, 平均奖励为：-121.64608051598093
# 当前迭代次数为：93, 当前奖励为：-140.9803969973209, 平均奖励为：-121.4864156657707
# 当前迭代次数为：94, 当前奖励为：-127.57343042756875, 平均奖励为：-122.33398744867266
# 当前迭代次数为：95, 当前奖励为：-132.94782358930095, 平均奖励为：-124.26218815892908
# 当前迭代次数为：96, 当前奖励为：-92.23807161172843, 平均奖励为：-123.07252701258085
# 当前迭代次数为：97, 当前奖励为：-107.73302486097462, 平均奖励为：-121.08059595157404
# 当前迭代次数为：98, 当前奖励为：-80.92146134941457, 平均奖励为：-117.1698402069109
# 当前迭代次数为：99, 当前奖励为：-89.8368397908207, 平均奖励为：-114.7047013531635
# 当前迭代次数为：100, 当前奖励为：-172.08516767933605, 平均奖励为：-119.02394652254024
# 当前迭代次数为：101, 当前奖励为：-81.78942074458557, 平均奖励为：-114.389943370255
# 当前迭代次数为：102, 当前奖励为：-83.20622746354827, 平均奖励为：-110.93118645145987
# 当前迭代次数为：103, 当前奖励为：-131.43388302412595, 平均奖励为：-109.97653505414038
# 当前迭代次数为：104, 当前奖励为：-151.78966587412825, 平均奖励为：-112.39815859879634
# 当前迭代次数为：105, 当前奖励为：-113.34625218271343, 平均奖励为：-110.43800145813756
# 当前迭代次数为：106, 当前奖励为：-160.5093309127593, 平均奖励为：-117.26512738824067
# 当前迭代次数为：107, 当前奖励为：-174.81800735082112, 平均奖励为：-123.97362563722531
# 当前迭代次数为：108, 当前奖励为：-136.73850656510143, 平均奖励为：-129.555330158794
# 当前迭代次数为：109, 当前奖励为：-81.54408025820544, 平均奖励为：-128.72605420553248
# 当前迭代次数为：110, 当前奖励为：-83.77098683645073, 平均奖励为：-119.89463612124396
# 当前迭代次数为：111, 当前奖励为：-117.86410692735751, 平均奖励为：-123.50210473952116
# 当前迭代次数为：112, 当前奖励为：-133.30196056803848, 平均奖励为：-128.5116780499702
# 当前迭代次数为：113, 当前奖励为：-78.1362913379024, 平均奖励为：-123.1819188813478
# 当前迭代次数为：114, 当前奖励为：-77.84738196093035, 平均奖励为：-115.78769049002801
# 当前迭代次数为：115, 当前奖励为：-94.5939201769881, 平均奖励为：-113.91245728945549
# 当前迭代次数为：116, 当前奖励为：-125.97176285932656, 平均奖励为：-110.45870048411223
# 当前迭代次数为：117, 当前奖励为：-119.13024075672618, 平均奖励为：-104.88992382470272
# 当前迭代次数为：118, 当前奖励为：-83.36205652143063, 平均奖励为：-99.55227882033564

# %%
import pandas as pd

# 创建一个DataFrame对象
df = pd.DataFrame({'return_list': return_list})

# 将DataFrame保存到CSV文件
df.to_csv('../../../../results/example/PPO/PPO+量子电路/只有量子电路规范化/return_list_MC', index=False)  # 可以指定文件名和是否包括行索引
actor.save_weights('../../../../results/example/PPO/PPO+量子电路/只有量子电路规范化/weights_MC_ACTOR_NO_amsgrad.h5')
critic.save_weights('../../../../results/example/PPO/PPO+量子电路/只有量子电路规范化/weights_MC_CRITIC_NO_amsgrad.h5')

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(return_list)
plt.xlabel('Epsiode')
plt.ylabel('Collected rewards')
plt.show()
